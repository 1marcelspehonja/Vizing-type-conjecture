# %%
def graf(prvi, drugi, k):

    poln_graf = graphs.CompleteGraph(k)

    kartezijski_prvega_in_polnega = prvi.cartesian_product(poln_graf)
    kartezijski_drugega_in_polnega = drugi.cartesian_product(poln_graf)

    kartezijski_prvega_in_drugega = drugi.cartesian_product(prvi)
    kartezijski_kartezijskega = kartezijski_prvega_in_drugega.cartesian_product(poln_graf)

    krt_prvega = kartezijski_prvega_in_polnega.dominating_set(value_only=True, total=True)
    krt_drugega = kartezijski_drugega_in_polnega.dominating_set(value_only=True, total=True)
    krt_obeh = kartezijski_kartezijskega.dominating_set(value_only=True, total=True)
    
    return (krt_prvega * krt_drugega) / krt_obeh

# %%
#vseh dvodelnih grafov z do 6 vozlišč je 27
tdo5 = []
for G in graphs.nauty_geng('2 -c -b'):
    tdo5.append(G)
for G in graphs.nauty_geng('3 -c -b'):
    tdo5.append(G)
for G in graphs.nauty_geng('4 -c -b'):
    tdo5.append(G)
for G in graphs.nauty_geng('5 -c -b'):
    tdo5.append(G)
t6 = []
for G in graphs.nauty_geng('6 -c -b'):
    t6.append(G)
    
tdo6 = tdo5 + t6 

len(tdo6)
#len(tdo5)
# Out:
# 27

# %%
k = 2
seznam_grafov = tdo6
rezultati_do_6_vozlisc_k2 = []
for i in range(len(tdo6)):
    for j in range(i, len(seznam_grafov)):
        rezultati_do_6_vozlisc_k2.append((k, i, j, graf(seznam_grafov[i], seznam_grafov[j], k)))
        print (rezultati_do_6_vozlisc_k2[-1]);

#algoritem poda seznam resitev (k, prvi_graf, drugi_graf, iskan_koeficient) - vseh moznosti je 351 - k=2

# %%
q = []
seznam_resitev = rezultati_do_6_vozlisc_k2
for i in range(len(seznam_resitev)):
    t = []
    for j in range(len(q)):
        t.append(q[j][1])
    if t == []:
        q.append((i, seznam_resitev[i][3]))
    elif seznam_resitev[i][3] > max(t):
        q = [(i, seznam_resitev[i][3])]
    elif seznam_resitev[i][3] == max(t):
        q.append((i, seznam_resitev[i][3]))
print q

#algoritem nam poda seznam tistih resitev pri katerih imamo maximum  (element_po_vrsti_iz_seznama_resitev, max_koeficient)
# Out:
# [(4, 2), (8, 2), (17, 2), (78, 2), (79, 2), (83, 2), (92, 2), (93, 2), (102, 2), (106, 2), (115, 2), (116, 2), (198, 2), (324, 2), (333, 2)]

# %%
w = []
seznam_resitev = rezultati_do_6_vozlisc_k2
for i in range(len(seznam_resitev)):
    t = []
    for j in range(len(w)):
        t.append(w[j][1])
    if t == []:
        w.append((i, seznam_resitev[i][3]))
    elif seznam_resitev[i][3] < min(t):
        w = [(i, seznam_resitev[i][3])]
    elif seznam_resitev[i][3] == min(t):
        w.append((i, seznam_resitev[i][3]))
print w

#algoritem nam poda seznam tistih resitev pri katerih imamo minimum  (element_po_vrsti_iz_seznama_resitev, min_koeficient)
# Out:
# [(225, 1/3)]

# %%
for i in range(len(q)):
    print(rezultati_do_6_vozlisc_k2[q[i][0]])
# Out:
# (2, 0, 4, 2)
# (2, 0, 8, 2)
# (2, 0, 17, 2)
# (2, 3, 3, 2)
# (2, 3, 4, 2)
# (2, 3, 8, 2)
# (2, 3, 17, 2)
# (2, 3, 18, 2)
# (2, 4, 4, 2)
# (2, 4, 8, 2)
# (2, 4, 17, 2)
# (2, 4, 18, 2)
# (2, 8, 18, 2)
# (2, 17, 18, 2)
# (2, 18, 18, 2)

# %%
tdo6[18]    #se ponovi v 6 od 15 najboljših rešitev
# Out:
# Graph on 6 vertices

# %%
k = 3
seznam_grafov = tdo6
rezultati_do_6_vozlisc = []
for i in range(len(tdo6)):
    for j in range(i, len(seznam_grafov)):
        rezultati_do_6_vozlisc.append((k, i, j, graf(seznam_grafov[i], seznam_grafov[j], k)))
        print (rezultati_do_6_vozlisc[-1]);

#algoritem poda seznam resitev (k, prvi_graf, drugi_graf, iskan_koeficient) - vseh moznosti je 351 - k=3

# %%
q = []
seznam_resitev = rezultati_do_6_vozlisc
for i in range(len(seznam_resitev)):
    t = []
    for j in range(len(q)):
        t.append(q[j][1])
    if t == []:
        q.append((i, seznam_resitev[i][3]))
    elif seznam_resitev[i][3] > max(t):
        q = [(i, seznam_resitev[i][3])]
    elif seznam_resitev[i][3] == max(t):
        q.append((i, seznam_resitev[i][3]))
print q
# Out:
# [(26, 5/3), (52, 5/3), (101, 5/3), (121, 5/3), (122, 5/3), (123, 5/3), (124, 5/3), (167, 5/3), (224, 5/3), (299, 5/3), (341, 5/3), (349, 5/3), (356, 5/3)]

# %%
w = []
seznam_resitev = rezultati_do_6_vozlisc
for i in range(len(seznam_resitev)):
    t = []
    for j in range(len(w)):
        t.append(w[j][1])
    if t == []:
        w.append((i, seznam_resitev[i][3]))
    elif seznam_resitev[i][3] < min(t):
        w = [(i, seznam_resitev[i][3])]
    elif seznam_resitev[i][3] == min(t):
        w.append((i, seznam_resitev[i][3]))
print w
# Out:
# [(225, 9/16)]

# %%
for i in range(len(q)):
    print(rezultati_do_6_vozlisc[q[i][0]])
# Out:
# (3, 0, 26, 5/3)
# (3, 1, 26, 5/3)
# (3, 3, 26, 5/3)
# (3, 4, 23, 5/3)
# (3, 4, 24, 5/3)
# (3, 4, 25, 5/3)
# (3, 4, 26, 5/3)
# (3, 6, 26, 5/3)
# (3, 9, 26, 5/3)
# (3, 14, 26, 5/3)
# (3, 18, 26, 5/3)
# (3, 19, 26, 5/3)
# (3, 20, 26, 5/3)

# %%
tdo6[26]    #se ponovi v 10 od 13 najboljših rešitev
# Out:
# Graph on 6 vertices

# %%
k = 4
seznam_grafov = tdo6
rezultati_do_6_vozlisc_k4 = []
for i in range(0, len(tdo6)):
    for j in range(i, len(seznam_grafov)):
        rezultati_do_6_vozlisc_k4.append((k, i, j, graf(seznam_grafov[i], seznam_grafov[j], k)))
        print (rezultati_do_6_vozlisc_k4[-1]);

#algoritem poda seznam resitev (k, prvi_graf, drugi_graf, iskan_koeficient) - vseh moznosti je 351 - k=4

# %%
q = []
seznam_resitev = rezultati_do_6_vozlisc_k4
for i in range(len(seznam_resitev)):
    t = []
    for j in range(len(q)):
        t.append(q[j][1])
    if t == []:
        q.append((i, seznam_resitev[i][3]))
    elif seznam_resitev[i][3] > max(t):
        q = [(i, seznam_resitev[i][3])]
    elif seznam_resitev[i][3] == max(t):
        q.append((i, seznam_resitev[i][3]))
print q
# Out:
# [(187, 30/19), (224, 30/19)]

# %%
w = []
seznam_resitev = rezultati_do_6_vozlisc_k4
for i in range(len(seznam_resitev)):
    t = []
    for j in range(len(w)):
        t.append(w[j][1])
    if t == []:
        w.append((i, seznam_resitev[i][3]))
    elif seznam_resitev[i][3] < min(t):
        w = [(i, seznam_resitev[i][3])]
    elif seznam_resitev[i][3] == min(t):
        w.append((i, seznam_resitev[i][3]))
print w
# Out:
# [(225, 4/5), (232, 4/5), (321, 4/5)]

# %%
for i in range(len(q)):
    print(rezultati_do_6_vozlisc_k4[q[i][0]])
# Out:
# (4, 7, 26, 30/19)
# (4, 9, 26, 30/19)

# %%
tdo6[26]    #se ponovi v obeh najboljših rešitvah
# Out:
# Graph on 6 vertices
